# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **EDA**

# %%
df_2021 = pd.read_csv('/content/drive/MyDrive/data_bootcamp/DS_project/2021_data.csv')
df_2023 = pd.read_csv('/content/drive/MyDrive/data_bootcamp/DS_project/2023_data.csv')

# %%
data_2021=df_2021.iloc[:, :8]
plt.figure(figsize = (8, 5))
sns.heatmap(data_2021.corr(), annot = True, cmap="YlGnBu")
plt.show()
# Out:
# <ipython-input-5-b5ea6e3d3245>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data_2021.corr(), annot = True, cmap="YlGnBu")

# %%
value_counts = df_2021['elevator'].value_counts()

# Print the counts
print(value_counts)
# Out:
# 1.0    136787
# 0.0     33737
# Name: elevator, dtype: int64

# %%
data_2023=df_2023.iloc[:, :8]
plt.figure(figsize = (8, 5))
color = plt.get_cmap('YlGnBu')   # default color
color.set_bad('lightblue')
sns.heatmap(data_2023[:8].corr(), annot = True, cmap=color)
plt.show()
# Out:
# <ipython-input-7-a8ace652b715>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data_2023[:8].corr(), annot = True, cmap=color)
